# %%
import duckdb

pd = duckdb.read_parquet("https://data.kijang.net/dea/donations/historical.parquet").df()

pd
# Out:
#            inst_code visit_date previous_visit  donation_type  \
# 0        11-14010001 2006-01-01     1800-08-10              1
# 1        11-02030085 2006-01-01     2005-12-18              1
# 2        11-02030085 2006-01-01     2005-06-30              1
# 3        11-14010001 2006-01-01     1800-08-10              1
# 4        11-14010001 2006-01-01     1800-08-10              1
# ...              ...        ...            ...            ...
# 9331990  11-04030005 2025-10-29     2025-02-24              1
# 9331991  11-04030005 2025-10-29     2025-04-08              1
# 9331992  11-04030005 2025-10-29     1800-08-10              1
# 9331993  11-04030005 2025-10-29     1800-08-10              1
# 9331994  11-14010001 2025-10-29     2025-08-15              1
#
#         donation_location classification_id blood_group
# 0                       M                 C           B
# 1                       U                 C           B
# ...

# %%
# Out:
# This inst is not in excel 11-01020400
# This inst is not in excel 11-05070013
# This inst is not in excel 11-08010020
# This inst is not in excel 11-08010023
# This inst is not in excel 11-08020024
# This inst is not in excel 11-08090013
