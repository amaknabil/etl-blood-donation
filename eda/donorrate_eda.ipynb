# %%
import duckdb
import matplotlib.pyplot as plt

con = duckdb.connect("../blood_data.duckdb")

# %%
df = con.execute("select * from read_parquet('https://data.kijang.net/dea/donations/2025-11-01')").df()

df
# Out:
#           inst_code gender  race  birth_date     latest  age
# 0       11-01010011      M     3        2002 2025-11-24   23
# 1       11-01010011      M     3        1969 2025-11-24   56
# 2       11-01010011      M     6        1973 2025-11-24   52
# 3       11-01010011      M     1        1973 2025-11-24   52
# 4       11-01010011      M     3        1985 2025-11-24   40
# ...             ...    ...   ...         ...        ...  ...
# 642436  11-14010001      F     3        1999 2024-01-01   25
# 642437  11-14010001      M    11        1972 2024-01-01   52
# 642438  11-14010001      F     3        1978 2024-01-01   46
# 642439  11-14010001      M    11        1978 2024-01-01   46
# 642440  11-14010001      M     3        1985 2024-01-01   39
#
# [642441 rows x 6 columns]

# %%
con.close()
