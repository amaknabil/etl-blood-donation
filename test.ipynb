# %%
db_list = [
    "11-01010011", "11-01020010","11-01020400","11-02030085","11-03040012","11-04030005","11-05060009","11-05070013", "11-06050013",
    "11-06110022","11-07030013","11-07050009","11-08010020","11-08010023","11-08020024","11-08050011","11-08070022","11-08080019","11-08090013",
    "11-10040013", "11-11050009", "11-12060388", "11-12170028", "11-12210043","11-13110018","11-13190029","11-13270034","11-14010001"
]

excel_list = [
    "11-01010011","11-01020010","11-02030085","11-03040012","11-04030005","11-05060009","11-06050013","11-06110022","11-07030013",
    "11-07050009","11-08050011","11-08070022","11-08080019","11-10040013","11-11050009","11-12060388","11-12170028","11-12210043",
    "11-13110018","11-13190029","11-13270034","11-14010001"
]



print(len(db_list))
print(len(excel_list))
# Out:
# 28
# 22

# %%
for list_db in db_list:
    isFound = False
    for list_excel in excel_list:
        if list_db == list_excel:
            # print("Found")
            isFound = True
            break
    if (not isFound):
            print(f"This inst is not in excel {list_db}")
# Out:
# This inst is not in excel 11-01020400
# This inst is not in excel 11-05070013
# This inst is not in excel 11-08010020
# This inst is not in excel 11-08010023
# This inst is not in excel 11-08020024
# This inst is not in excel 11-08090013
