# %%
# Out:
# https://data.kijang.net/dea/donations/2025-10-29.parquet2025-11-03.parquet
# Fail because: HTTP Error: Unable to connect to URL "https://data.kijang.net/dea/donations/2025-10-29.parquet2025-11-03.parquet": 404 (Not Found).
